# %%
# Ввод переменных
n = int(input())

A = tuple()
for i in range(n):
    a, b = map(int, input().split())
    A += (a, b),
A

# %%
# A = ((1, 5), (8, 2), (4, 4), (10, 4), (1, 3))
A = ((1, 5), (8, 2), (4, 4))
A = ((7,6), (7,4))
A = ((14, 1), (7, 4), (1, 14))

pos = [[]] * 10
neg = [[]] * 10
def make_seq(pos, go_ans=True):
    my_string = ''
    max_height = 0 
    height = 0
    for i in range(len(pos)):
        if len(pos[i]) > 1:
            for el in sorted(pos[i], reverse=True):
                my_string += str(el[2]) + ' '
                a, b = el[0], el[1]
        elif len(pos[i]) == 1:
            my_string += str(pos[i][0][2]) + ' '
            a, b = pos[i][0][0], pos[i][0][1]
        else:
            continue

        height += a
        if height > max_height:
            max_height = height
        height -= b
        
    if go_ans == True:
        print(max_height)
    return my_string


count = 1
for i in range(len(A)):
    a, b = A[i]
    result = a - b
    if result >= 0:
        if result > len(pos):
            up = (result - len(pos)) + 1
            pos += [[]] * up
            
        val = (A[i]) + (count,)
        if len(pos[result]) == 0:
            pos[result] = [val]
        else:
            pos[result].append(val)
    else:
        result = abs(result)
        if result > len(neg):
            up = (result - len(neg)) + 1
            neg += [[]] * up

        val = (A[i]) + (count,)
        if len(neg[result]) == 0:
            neg[result] = [val]
        else:
            neg[result].append(val)
            
    count += 1

pos = pos[::-1] # переворот списка для нужного порядка
my_string = ''
my_string += make_seq(pos)
my_string += make_seq(neg, False)
print(my_string)

# print('neg', neg)
# print('pos', pos)

# %%
n = int(input())

A = tuple()
for i in range(n):
    a, b = map(int, input().split())
    A += (a, b),

pos = [[]] * 10
neg = [[]] * 10
def make_seq(pos, go_ans=True):
    my_string = ''
    max_height = 0 
    height = 0
    for i in range(len(pos)):
        if len(pos[i]) > 1:
            for el in sorted(pos[i], reverse=True):
                my_string += str(el[2]) + ' '
                a, b = el[0], el[1]
        elif len(pos[i]) == 1:
            my_string += str(pos[i][0][2]) + ' '
            a, b = pos[i][0][0], pos[i][0][1]
        else:
            continue

        height += a
        if height > max_height:
            max_height = height
        height -= b
        
    if go_ans == True:
        print(max_height)
    return my_string


count = 1
for i in range(len(A)):
    a, b = A[i]
    result = a - b
    if result >= 0:
        if result > len(pos):
            up = (result - len(pos)) + 1
            pos += [[]] * up
            
        val = (A[i]) + (count,)
        if len(pos[result]) == 0:
            pos[result] = [val]
        else:
            pos[result].append(val)
    else:
        result = abs(result)
        if result > len(neg):
            up = (result - len(neg)) + 1
            neg += [[]] * up

        val = (A[i]) + (count,)
        if len(neg[result]) == 0:
            neg[result] = [val]
        else:
            neg[result].append(val)
            
    count += 1

pos = pos[::-1] # переворот списка для нужного порядка
my_string = ''
my_string += make_seq(pos)
my_string += make_seq(neg, False)
print(my_string)

# %%
160714711 - 449656269

# %%
# Ввод переменных
n = int(input())
pos = []
neg = []
count = 1
for i in range(n):
    a, b = map(int, input().split())
    result = a - b
    if result >= 0:
        pos.append((result, a, b, count))
    else:
        neg.append((abs(result), a, b, count))
    
    count += 1


print(pos)
print(sorted(neg))

# %%
# pos = [(6, 8, 2, 2), (10, 12, 2, 4), (3, 4, 1, 5),
#        (1, 8, 7, 6), (1, 8, 7, 7), (10, 22, 12, 8),
#       (10, 11, 1, 9)]
# neg = [(4, 1, 5, 1), (0, 4, 4, 3)]

pos = sorted(pos, reverse=True)

my_string = ''
max_height = 0 
height = 0

for i in range(len(pos)):
    my_string += str(pos[i][3]) + ' '
    a, b = pos[i][1], pos[i][2]
    height += a
    if height > max_height:
        max_height = height
    height -= b

for i in range(len(neg)): 
    my_string += str(neg[i][3]) + ' '

print(max_height)
print(my_string)



# print(sorted(pos, reverse=True))
# print(sorted(neg))

# %%
# Ввод переменных
n = int(input())
pos = []
neg = []
count = 1
for i in range(n):
    a, b = map(int, input().split())
    result = a - b
    if result >= 0:
        pos.append((result, a, b, count))
    else:
        neg.append((abs(result), a, b, count))
    
    count += 1

pos = sorted(pos, reverse=True)

my_string = ''
max_height = 0 
height = 0

for i in range(len(pos)):
    my_string += str(pos[i][3]) + ' '
    a, b = pos[i][1], pos[i][2]
    height += a
    if height > max_height:
        max_height = height
    height -= b

for i in range(len(neg)): 
    my_string += str(neg[i][3]) + ' '

print(max_height)
print(my_string)

# %%
# Ввод переменных
n = 7
A = ((160714711, 449656269), (822889311, 446755913), (135599877, 389312924), 
     (480845266, 448565595), (561330066, 605997004), (61020590, 573085537),
     (715477619, 181424399)
    )

pos = []
neg = []
count = 1
for i in range(n):
    a, b = A[i]
    result = a - b
    if result >= 0:
        pos.append((result, a, b, count))
    else:
        neg.append((abs(result), a, b, count))
    
    count += 1

pos = sorted(pos, reverse=True)

print(pos)
print()
print(neg)

my_string = ''
max_height = 0 
height = 0

for i in range(len(pos)):
    my_string += str(pos[i][3]) + ' '
    a, b = pos[i][1], pos[i][2]
    height += a
    if height > max_height:
        max_height = height
    height -= b

for i in range(len(neg)): 
    my_string += str(neg[i][3]) + ' '
    a, b = neg[i][1], neg[i][2]
    height += a
    if height > max_height:
        max_height = height
    height -= b


print(max_height)
print(my_string)

# %%
ans = 1503796355 # 2 4 7 5 1 3 6 
a_2 = (822889311 ,446755913)
a_4 = (480845266, 448565595)
a_7 = (715477619, 181424399)
a_5 = (561330066, 605997004)

# %%
a_2[0] - a_2[1] + a_4[0] - a_4[1] + a_7[0] - a_7[1] + a_5[0]

# %%
pos = []
neg = []
start_pos = 0
with open(r"F:\Загрузки\04.txt", 'r+') as test_8:
    lines = test_8.readlines()
    n = int(lines[0])
    count = 0
    for i in range(n):
        a, b = map(int, lines[i+1].strip().split())
        result = a - b
        if result >= 0:
            pos.append([a, b, result, i+1])
            if a > start_pos:
                start_pos = a
                count_pos = count
                s_b, s_result, s_index = b, result, i+1
                
            count += 1
                
        else:
            neg.append([a, b, result, i+1])
  
[print(el) for el in sorted(pos, reverse=True)];
print()
[print(el) for el in sorted(neg, reverse=True)];

# %%
pos = sorted(pos, reverse=True)
start_val = pos.pop(0)

# %%
def diff_sort(pos):
    for i in range(len(pos)):
        for j in range(len(pos)):
            if pos[i][2] < pos[j][2]:
                pos[i], pos[j] = pos[j], pos[i]
    return pos

# %%
neg = sorted(neg, reverse=True)

# %%
together = [start_val] + pos + neg

# %%
def snails_answer(together):
    string_order = ''
    max_value = 0
    value = 0
    for i in range(len(together)):
        string_order += str(together[i][3]) + ' '
        value += together[i][0]
        if value > max_value:
            max_value = value
        value -= together[i][1]
    
    print(max_value, string_order, sep='\n')

# %%
def diff_sort(pos):
    for i in range(len(pos)):
        for j in range(len(pos)):
            if pos[i][2] < pos[j][2]:
                pos[i], pos[j] = pos[j], pos[i]
    return pos

def snails_answer(together):
    string_order = ''
    max_value = 0
    value = 0
    value_old = 1
    for i in range(len(together)):
        string_order += str(together[i][3]) + ' '
        value += together[i][0]
        # print(value, round(value-value_old, 4))
        if value > max_value:
            max_value = value
        value_old = value
        value -= together[i][1]
    print(max_value, string_order, sep='\n')   


pos = []
neg = []
# with open(r"F:\Загрузки\04.txt", 'r+') as test_8:
#     lines = test_8.readlines()
#     n = int(lines[0])
#     for i in range(n):
#         a, b = map(int, lines[i+1].strip().split())
#         result = a - b
#         if result >= 0:
#             pos.append([a, b, result, i+1])    
#         else:
#             neg.append([a, b, result, i+1])

# n = int(input())
n = 2
A = ['7 6', '7 4']
for i in range(n):
    a, b = map(int, A[i].strip().split())
    result = a - b
    if result >= 0:
        pos.append([a, b, result, i+1])    
    else:
        neg.append([a, b, result, i+1])

pos = sorted(pos, reverse=True)
# [pos[i][0] for i in range(len(pos))]
for i in range()
pos[0][0]




# print(pos)
start_val = pos.pop(0)
pos = diff_sort(pos)
neg = sorted(neg, reverse=True)
together = [start_val] + pos + neg
snails_answer(together)
# together
# Out:
# 8
# 1 2

# %%
534053220 + 822889311
# Out:
# 1356942531

# %%
822889311 + 480845266 + 715477619 + 561330066 - 446755913 - 448565595 - 181424399
# Out:
# 1503796355
